# %% [markdown]
# # Library

# %%
from Module.Global_variable import os, time, torch, np, pd, plt
from Module.utils.Convenience_Function import save_pickle, time_checker
import Module.process1.preparatory_items as p1pi
from Module.process1.index_dictionary_maker import get_index_dictionary
from Module.process1.pipeLine import model_pipeline

# %% [markdown]
# # Global Variable

# %%
# Process 시작 전 정의 사항
#####################################################################################
_MAKE_NEW_DIRECTORY = False    # directory 생성
_MAKE_NEW_INDEX_DICT = False   # Index dictionary를 새로 생성할 것인지
# Log를 출력할 것인지
_VERBOSE = True
# Train 중 log를 저장할 것인지
_SAVE_TRAIN_LOG = True
# Time iteration log를 저장할 것인지
_SAVE_ITER_LOG = True
# 사용할 GPU 번호
_GPU_NUMBER = 2
torch.cuda.set_device(_GPU_NUMBER)   # set basic gpu
# torch._dynamo 캐시 한계치 조정
torch._dynamo.config.cache_size_limit = 64   # Default
# 모델 저장 여부
_MODEL_SAVE_BOOL = True
#####################################################################################


# 학습 간 전역 변수 설정
#####################################################################################
# process 기초 디렉터리 생성
p1pi.make_process_start_dir(makes_new=_MAKE_NEW_DIRECTORY)
# index dictionary with Data Loader
_IDX_DICT = get_index_dictionary(process_boolean=_MAKE_NEW_INDEX_DICT).process()
#####################################################################################


# Model 학습 관련 변수 설정
#####################################################################################
_PROCESS_SET_DICT = p1pi.get_process_set_dict(
    model_save=_MODEL_SAVE_BOOL,        # 모델 저장 여부
    save_iter_time_log=_SAVE_ITER_LOG,  # iteration의 time log 저장 여부
    save_train_log=_SAVE_TRAIN_LOG,     # 학습 과정에사 발생하는 주요 issue의 저장 여부
    verbose=_VERBOSE
)
_MODEL_SET_DICT = p1pi.get_model_set_dict(
    model_key="retinaNet",
    cnn_key="resnet50_v2",
    optimizer_key="AdamW"
)
_HYPER_PARAMS_DICT = p1pi.get_HP_set_dict(
    learing_rate=0.00001, weight_decay=0.005,
    T_0=20, T_mult=2, eta_min=0.00000001,
    CS_threshold=0.5,   # 모델의 추론 결과에 대하여 Confidence socre의 threshold
    iou_threshold=0.3   # NMS에 적용될 IoU의 threshold
)
#####################################################################################

# %% [markdown]
# # Process

# %%
for k in range(_PROCESS_SET_DICT["k_size"]):
    
    # Model 학습을 위한 Instance 생성
    MTnE_Ob = model_pipeline(
        p_set_dict=_PROCESS_SET_DICT, m_set_dict=_MODEL_SET_DICT, hp_dict=_HYPER_PARAMS_DICT,
        idx_dict=_IDX_DICT, gpu_num=_GPU_NUMBER
    )
    # DataLoader와 predict에 사용될 idx_dict(pred_idx_dict)를 정의한다.
    MTnE_Ob.define_k_Loader_and_idx_dict(k)
    # Model 정의
    MTnE_Ob.import_model()
    # Optimizer(Scheduler, Scaler) 정의
    MTnE_Ob.import_optimizer_and_scheduler()
    # 주요 Instance 생성
    MTnE_Ob.make_important_Instance(k)
    
    MTnE_Ob.Iter_log_Ins.make_log_file()      # 해당 Dataset에 대한 신규 Log file 생성
    MTnE_Ob.make_train_log_path_and_file(k)   # 해당 train에 대한 train_log의 경로 및 파일 생성
    MTnE_Ob.make_model_save_path(k)           # model 저장 경로 생성
    
    # 모델의 학습 및 추론 실시.
    loss_dict, score_dict, predict_dict = MTnE_Ob.model_train_and_evaluate()
    
    break
# Out:
# Epochs:  1/200 [train][=============================================================] (1114/1114) [time] 0:06:49.59 total loss: 0.2117 [Loss ]  | classification 0.1189 | bbox_regression 0.0928
# Epochs:  1/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.44 total loss: 0.0865 [Score]  | AP(AP@[.50:.05:.95]) 0.5155 | AP50 0.7473 | AP75 0.6193 | precision 0.9800 | recall 0.7509 | f1_score 0.8502
# save check point: [before]: inf / [now]: 0.086471 - Saving model...
# Epochs:  2/200 [train][=============================================================] (1114/1114) [time] 0:07:08.90 total loss: 0.1219 [Loss ]  | classification 0.0488 | bbox_regression 0.0731
# Epochs:  2/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.02 total loss: 0.0722 [Score]  | AP(AP@[.50:.05:.95]) 0.6109 | AP50 0.8520 | AP75 0.7276 | precision 0.9940 | recall 0.8536 | f1_score 0.9185
# save check point: [before]: 0.086471 / [now]: 0.072207 - Saving model...
# Epochs:  3/200 [train][=============================================================] (1114/1114) [time] 0:07:30.77 total loss: 0.1089 [Loss ]  | classification 0.0405 | bbox_regression 0.0684
# Epochs:  3/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.60 total loss: 0.0693 [Score]  | AP(AP@[.50:.05:.95]) 0.6914 | AP50 0.9387 | AP75 0.8303 | precision 0.9922 | recall 0.9421 | f1_score 0.9665
# save check point: [before]: 0.072207 / [now]: 0.069285 - Saving model...
# Epochs:  4/200 [train][=============================================================] (1114/1114) [time] 0:07:21.70 total loss: 0.0955 [Loss ]  | classification 0.0328 | bbox_regression 0.0627
# Epochs:  4/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.68 total loss: 0.0623 [Score]  | AP(AP@[.50:.05:.95]) 0.6555 | AP50 0.8754 | AP75 0.8086 | precision 0.9948 | recall 0.8777 | f1_score 0.9326
# save check point: [before]: 0.069285 / [now]: 0.062275 - Saving model...
# Epochs:  5/200 [train][=============================================================] (1114/1114) [time] 0:07:16.41 total loss: 0.0967 [Loss ]  | classification 0.0326 | bbox_regression 0.0641
# Epochs:  5/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.70 total loss: 0.0648 [Score]  | AP(AP@[.50:.05:.95]) 0.6629 | AP50 0.8895 | AP75 0.8170 | precision 0.9955 | recall 0.8912 | f1_score 0.9405
# Epochs:  6/200 [train][=============================================================] (1114/1114) [time] 0:07:20.26 total loss: 0.0918 [Loss ]  | classification 0.0325 | bbox_regression 0.0592
# Epochs:  6/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:13.56 total loss: 0.0570 [Score]  | AP(AP@[.50:.05:.95]) 0.6525 | AP50 0.8519 | AP75 0.8015 | precision 0.9954 | recall 0.8537 | f1_score 0.9191
# save check point: [before]: 0.062275 / [now]: 0.056976 - Saving model...
# Epochs:  7/200 [train][=============================================================] (1114/1114) [time] 0:07:08.54 total loss: 0.0876 [Loss ]  | classification 0.0288 | bbox_regression 0.0588
# Epochs:  7/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.25 total loss: 0.0558 [Score]  | AP(AP@[.50:.05:.95]) 0.6918 | AP50 0.9018 | AP75 0.8520 | precision 0.9956 | recall 0.9032 | f1_score 0.9472
# save check point: [before]: 0.056976 / [now]: 0.055754 - Saving model...
# Epochs:  8/200 [train][=============================================================] (1114/1114) [time] 0:07:19.70 total loss: 0.0811 [Loss ]  | classification 0.0240 | bbox_regression 0.0571
# Epochs:  8/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.47 total loss: 0.0561 [Score]  | AP(AP@[.50:.05:.95]) 0.7015 | AP50 0.9064 | AP75 0.8562 | precision 0.9950 | recall 0.9078 | f1_score 0.9494
# Epochs:  9/200 [train][=============================================================] (1114/1114) [time] 0:07:17.73 total loss: 0.0790 [Loss ]  | classification 0.0231 | bbox_regression 0.0559
# Epochs:  9/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.22 total loss: 0.0547 [Score]  | AP(AP@[.50:.05:.95]) 0.7037 | AP50 0.9115 | AP75 0.8572 | precision 0.9950 | recall 0.9129 | f1_score 0.9522
# save check point: [before]: 0.055754 / [now]: 0.054725 - Saving model...
# Epochs: 10/200 [train][=============================================================] (1114/1114) [time] 0:07:24.10 total loss: 0.0834 [Loss ]  | classification 0.0265 | bbox_regression 0.0569
# Epochs: 10/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.51 total loss: 0.0535 [Score]  | AP(AP@[.50:.05:.95]) 0.7001 | AP50 0.9071 | AP75 0.8669 | precision 0.9963 | recall 0.9084 | f1_score 0.9503
# save check point: [before]: 0.054725 / [now]: 0.053541 - Saving model...
# Epochs: 11/200 [train][=============================================================] (1114/1114) [time] 0:07:11.61 total loss: 0.0824 [Loss ]  | classification 0.0263 | bbox_regression 0.0561
# Epochs: 11/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.72 total loss: 0.0551 [Score]  | AP(AP@[.50:.05:.95]) 0.7308 | AP50 0.9360 | AP75 0.8925 | precision 0.9910 | recall 0.9380 | f1_score 0.9637
# Epochs: 12/200 [train][=============================================================] (1114/1114) [time] 0:07:14.10 total loss: 0.0795 [Loss ]  | classification 0.0242 | bbox_regression 0.0554
# Epochs: 12/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.38 total loss: 0.0494 [Score]  | AP(AP@[.50:.05:.95]) 0.7000 | AP50 0.8930 | AP75 0.8545 | precision 0.9981 | recall 0.8941 | f1_score 0.9433
# save check point: [before]: 0.053541 / [now]: 0.049368 - Saving model...
# Epochs: 13/200 [train][=============================================================] (1114/1114) [time] 0:07:08.96 total loss: 0.0753 [Loss ]  | classification 0.0227 | bbox_regression 0.0526
# Epochs: 13/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.95 total loss: 0.0537 [Score]  | AP(AP@[.50:.05:.95]) 0.6703 | AP50 0.8479 | AP75 0.8200 | precision 0.9967 | recall 0.8492 | f1_score 0.9170
# Epochs: 14/200 [train][=============================================================] (1114/1114) [time] 0:07:20.64 total loss: 0.0727 [Loss ]  | classification 0.0211 | bbox_regression 0.0517
# Epochs: 14/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:16.07 total loss: 0.0477 [Score]  | AP(AP@[.50:.05:.95]) 0.7519 | AP50 0.9513 | AP75 0.9110 | precision 0.9970 | recall 0.9528 | f1_score 0.9744
# save check point: [before]: 0.049368 / [now]: 0.047736 - Saving model...
# Epochs: 15/200 [train][=============================================================] (1114/1114) [time] 0:06:59.36 total loss: 0.0711 [Loss ]  | classification 0.0203 | bbox_regression 0.0508
# Epochs: 15/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.75 total loss: 0.0521 [Score]  | AP(AP@[.50:.05:.95]) 0.7326 | AP50 0.9249 | AP75 0.8913 | precision 0.9957 | recall 0.9260 | f1_score 0.9596
# Epochs: 16/200 [train][=============================================================] (1114/1114) [time] 0:07:24.48 total loss: 0.0732 [Loss ]  | classification 0.0210 | bbox_regression 0.0522
# Epochs: 16/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.83 total loss: 0.0503 [Score]  | AP(AP@[.50:.05:.95]) 0.7287 | AP50 0.9159 | AP75 0.8828 | precision 0.9963 | recall 0.9169 | f1_score 0.9549
# Epochs: 17/200 [train][=============================================================] (1114/1114) [time] 0:07:28.48 total loss: 0.0698 [Loss ]  | classification 0.0188 | bbox_regression 0.0510
# Epochs: 17/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.48 total loss: 0.0484 [Score]  | AP(AP@[.50:.05:.95]) 0.7381 | AP50 0.9262 | AP75 0.8955 | precision 0.9963 | recall 0.9272 | f1_score 0.9605
# Epochs: 18/200 [train][=============================================================] (1114/1114) [time] 0:07:29.76 total loss: 0.0703 [Loss ]  | classification 0.0194 | bbox_regression 0.0509
# Epochs: 18/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.35 total loss: 0.0488 [Score]  | AP(AP@[.50:.05:.95]) 0.7411 | AP50 0.9302 | AP75 0.8976 | precision 0.9970 | recall 0.9312 | f1_score 0.9629
# Epochs: 19/200 [train][=============================================================] (1114/1114) [time] 0:07:14.68 total loss: 0.0727 [Loss ]  | classification 0.0211 | bbox_regression 0.0517
# Epochs: 19/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:16.26 total loss: 0.0566 [Score]  | AP(AP@[.50:.05:.95]) 0.7255 | AP50 0.9193 | AP75 0.8833 | precision 0.9933 | recall 0.9204 | f1_score 0.9554
# Epochs: 20/200 [train][=============================================================] (1114/1114) [time] 0:07:13.39 total loss: 0.0732 [Loss ]  | classification 0.0223 | bbox_regression 0.0509
# Epochs: 20/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.90 total loss: 0.0510 [Score]  | AP(AP@[.50:.05:.95]) 0.7476 | AP50 0.9428 | AP75 0.9050 | precision 0.9958 | recall 0.9437 | f1_score 0.9690
# Epochs: 21/200 [train][=============================================================] (1114/1114) [time] 0:07:27.18 total loss: 0.0717 [Loss ]  | classification 0.0214 | bbox_regression 0.0503
# Epochs: 21/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.40 total loss: 0.0513 [Score]  | AP(AP@[.50:.05:.95]) 0.7354 | AP50 0.9313 | AP75 0.8895 | precision 0.9976 | recall 0.9323 | f1_score 0.9638
# Epochs: 22/200 [train][=============================================================] (1114/1114) [time] 0:07:28.62 total loss: 0.0706 [Loss ]  | classification 0.0207 | bbox_regression 0.0499
# Epochs: 22/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:12.64 total loss: 0.0484 [Score]  | AP(AP@[.50:.05:.95]) 0.7139 | AP50 0.8972 | AP75 0.8569 | precision 0.9975 | recall 0.8981 | f1_score 0.9452
# Epochs: 23/200 [train][=============================================================] (1114/1114) [time] 0:07:16.51 total loss: 0.0693 [Loss ]  | classification 0.0198 | bbox_regression 0.0494
# Epochs: 23/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:13.60 total loss: 0.0490 [Score]  | AP(AP@[.50:.05:.95]) 0.7426 | AP50 0.9291 | AP75 0.8980 | precision 0.9951 | recall 0.9300 | f1_score 0.9615
# Epochs: 24/200 [train][=============================================================] (1114/1114) [time] 0:07:41.08 total loss: 0.0678 [Loss ]  | classification 0.0192 | bbox_regression 0.0485
# Epochs: 24/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:12.61 total loss: 0.0478 [Score]  | AP(AP@[.50:.05:.95]) 0.7387 | AP50 0.9240 | AP75 0.8940 | precision 0.9975 | recall 0.9249 | f1_score 0.9598
# Epochs: 25/200 [train][=============================================================] (1114/1114) [time] 0:07:17.63 total loss: 0.0671 [Loss ]  | classification 0.0188 | bbox_regression 0.0483
# Epochs: 25/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:13.57 total loss: 0.0482 [Score]  | AP(AP@[.50:.05:.95]) 0.7599 | AP50 0.9557 | AP75 0.9126 | precision 0.9929 | recall 0.9567 | f1_score 0.9745
# Epochs: 26/200 [train][=============================================================] (1114/1114) [time] 0:07:43.62 total loss: 0.0650 [Loss ]  | classification 0.0181 | bbox_regression 0.0469
# Epochs: 26/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:14.18 total loss: 0.0480 [Score]  | AP(AP@[.50:.05:.95]) 0.7424 | AP50 0.9250 | AP75 0.8953 | precision 0.9969 | recall 0.9260 | f1_score 0.9601
# Epochs: 27/200 [train][=============================================================] (1114/1114) [time] 0:07:24.30 total loss: 0.0658 [Loss ]  | classification 0.0180 | bbox_regression 0.0478
# Epochs: 27/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:13.24 total loss: 0.0466 [Score]  | AP(AP@[.50:.05:.95]) 0.7615 | AP50 0.9512 | AP75 0.9179 | precision 0.9970 | recall 0.9522 | f1_score 0.9741
# save check point: [before]: 0.047736 / [now]: 0.046591 - Saving model...
# Epochs: 28/200 [train][=============================================================] (1114/1114) [time] 0:07:20.05 total loss: 0.0639 [Loss ]  | classification 0.0176 | bbox_regression 0.0463
# Epochs: 28/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:14.61 total loss: 0.0462 [Score]  | AP(AP@[.50:.05:.95]) 0.7571 | AP50 0.9419 | AP75 0.9112 | precision 1.0000 | recall 0.9425 | f1_score 0.9704
# save check point: [before]: 0.046591 / [now]: 0.046235 - Saving model...
# Epochs: 29/200 [train][=============================================================] (1114/1114) [time] 0:07:25.25 total loss: 0.0645 [Loss ]  | classification 0.0176 | bbox_regression 0.0469
# Epochs: 29/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:14.45 total loss: 0.0456 [Score]  | AP(AP@[.50:.05:.95]) 0.7532 | AP50 0.9396 | AP75 0.9062 | precision 0.9994 | recall 0.9402 | f1_score 0.9689
# save check point: [before]: 0.046235 / [now]: 0.045566 - Saving model...
# Epochs: 30/200 [train][=============================================================] (1114/1114) [time] 0:07:18.01 total loss: 0.0623 [Loss ]  | classification 0.0162 | bbox_regression 0.0461
# Epochs: 30/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:13.03 total loss: 0.0457 [Score]  | AP(AP@[.50:.05:.95]) 0.7528 | AP50 0.9388 | AP75 0.9009 | precision 0.9970 | recall 0.9396 | f1_score 0.9675
# Epochs: 31/200 [train][=============================================================] (1114/1114) [time] 0:07:06.94 total loss: 0.0631 [Loss ]  | classification 0.0163 | bbox_regression 0.0467
# Epochs: 31/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:16.36 total loss: 0.0462 [Score]  | AP(AP@[.50:.05:.95]) 0.7487 | AP50 0.9327 | AP75 0.8988 | precision 0.9976 | recall 0.9334 | f1_score 0.9644
# Epochs: 32/200 [train][=============================================================] (1114/1114) [time] 0:07:26.20 total loss: 0.0624 [Loss ]  | classification 0.0161 | bbox_regression 0.0463
# Epochs: 32/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:16.20 total loss: 0.0444 [Score]  | AP(AP@[.50:.05:.95]) 0.7440 | AP50 0.9248 | AP75 0.8913 | precision 0.9975 | recall 0.9254 | f1_score 0.9601
# save check point: [before]: 0.045566 / [now]: 0.044401 - Saving model...
# Epochs: 33/200 [train][=============================================================] (1114/1114) [time] 0:07:17.29 total loss: 0.0608 [Loss ]  | classification 0.0154 | bbox_regression 0.0454
# Epochs: 33/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.81 total loss: 0.0458 [Score]  | AP(AP@[.50:.05:.95]) 0.7503 | AP50 0.9310 | AP75 0.9007 | precision 0.9976 | recall 0.9317 | f1_score 0.9635
# Epochs: 34/200 [train][=============================================================] (1114/1114) [time] 0:07:01.29 total loss: 0.0604 [Loss ]  | classification 0.0151 | bbox_regression 0.0453
# Epochs: 34/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:16.52 total loss: 0.0453 [Score]  | AP(AP@[.50:.05:.95]) 0.7567 | AP50 0.9413 | AP75 0.9097 | precision 0.9994 | recall 0.9419 | f1_score 0.9698
# Epochs: 35/200 [train][=============================================================] (1114/1114) [time] 0:07:17.78 total loss: 0.0591 [Loss ]  | classification 0.0144 | bbox_regression 0.0447
# Epochs: 35/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:16.52 total loss: 0.0454 [Score]  | AP(AP@[.50:.05:.95]) 0.7519 | AP50 0.9345 | AP75 0.9029 | precision 0.9982 | recall 0.9351 | f1_score 0.9656
# Epochs: 36/200 [train][=============================================================] (1114/1114) [time] 0:07:19.88 total loss: 0.0588 [Loss ]  | classification 0.0145 | bbox_regression 0.0443
# Epochs: 36/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.55 total loss: 0.0452 [Score]  | AP(AP@[.50:.05:.95]) 0.7495 | AP50 0.9322 | AP75 0.9014 | precision 0.9982 | recall 0.9328 | f1_score 0.9644
# Epochs: 37/200 [train][=============================================================] (1114/1114) [time] 0:07:16.66 total loss: 0.0618 [Loss ]  | classification 0.0155 | bbox_regression 0.0463
# Epochs: 37/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:16.68 total loss: 0.0497 [Score]  | AP(AP@[.50:.05:.95]) 0.7410 | AP50 0.9270 | AP75 0.8971 | precision 0.9976 | recall 0.9277 | f1_score 0.9613
# Epochs: 38/200 [train][=============================================================] (1114/1114) [time] 0:07:34.48 total loss: 0.0656 [Loss ]  | classification 0.0178 | bbox_regression 0.0478
# Epochs: 38/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.54 total loss: 0.0492 [Score]  | AP(AP@[.50:.05:.95]) 0.7357 | AP50 0.9150 | AP75 0.8845 | precision 0.9969 | recall 0.9157 | f1_score 0.9546
# Epochs: 39/200 [train][=============================================================] (1114/1114) [time] 0:07:27.49 total loss: 0.0626 [Loss ]  | classification 0.0175 | bbox_regression 0.0451
# Epochs: 39/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.42 total loss: 0.0460 [Score]  | AP(AP@[.50:.05:.95]) 0.7503 | AP50 0.9345 | AP75 0.9035 | precision 0.9982 | recall 0.9351 | f1_score 0.9656
# Epochs: 40/200 [train][=============================================================] (1114/1114) [time] 0:07:09.95 total loss: 0.0631 [Loss ]  | classification 0.0172 | bbox_regression 0.0459
# Epochs: 40/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.65 total loss: 0.0553 [Score]  | AP(AP@[.50:.05:.95]) 0.7360 | AP50 0.9176 | AP75 0.8865 | precision 0.9969 | recall 0.9186 | f1_score 0.9561
# Epochs: 41/200 [train][=============================================================] (1114/1114) [time] 0:07:24.55 total loss: 0.0609 [Loss ]  | classification 0.0161 | bbox_regression 0.0448
# Epochs: 41/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:16.32 total loss: 0.0492 [Score]  | AP(AP@[.50:.05:.95]) 0.7369 | AP50 0.9197 | AP75 0.8890 | precision 1.0000 | recall 0.9203 | f1_score 0.9585
# Epochs: 42/200 [train][=============================================================] (1114/1114) [time] 0:07:19.49 total loss: 0.0633 [Loss ]  | classification 0.0178 | bbox_regression 0.0455
# Epochs: 42/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:16.07 total loss: 0.0533 [Score]  | AP(AP@[.50:.05:.95]) 0.7505 | AP50 0.9400 | AP75 0.9031 | precision 0.9976 | recall 0.9408 | f1_score 0.9683
# Epochs: 43/200 [train][=============================================================] (1114/1114) [time] 0:07:11.85 total loss: 0.0617 [Loss ]  | classification 0.0167 | bbox_regression 0.0450
# Epochs: 43/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.20 total loss: 0.0577 [Score]  | AP(AP@[.50:.05:.95]) 0.7688 | AP50 0.9591 | AP75 0.9247 | precision 0.9970 | recall 0.9601 | f1_score 0.9782
# Epochs: 44/200 [train][=============================================================] (1114/1114) [time] 0:07:02.48 total loss: 0.0624 [Loss ]  | classification 0.0171 | bbox_regression 0.0453
# Epochs: 44/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:16.59 total loss: 0.0492 [Score]  | AP(AP@[.50:.05:.95]) 0.7440 | AP50 0.9277 | AP75 0.8876 | precision 0.9969 | recall 0.9288 | f1_score 0.9617
# Epochs: 45/200 [train][=============================================================] (1114/1114) [time] 0:07:29.71 total loss: 0.0609 [Loss ]  | classification 0.0162 | bbox_regression 0.0447
# Epochs: 45/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:16.65 total loss: 0.0618 [Score]  | AP(AP@[.50:.05:.95]) 0.7739 | AP50 0.9657 | AP75 0.9252 | precision 0.9965 | recall 0.9670 | f1_score 0.9815
# Epochs: 46/200 [train][=============================================================] (1114/1114) [time] 0:07:13.96 total loss: 0.0610 [Loss ]  | classification 0.0159 | bbox_regression 0.0452
# Epochs: 46/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:16.08 total loss: 0.0461 [Score]  | AP(AP@[.50:.05:.95]) 0.7267 | AP50 0.8956 | AP75 0.8666 | precision 0.9981 | recall 0.8964 | f1_score 0.9445
# Epochs: 47/200 [train][=============================================================] (1114/1114) [time] 0:07:12.84 total loss: 0.0603 [Loss ]  | classification 0.0155 | bbox_regression 0.0448
# Epochs: 47/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:16.41 total loss: 0.0453 [Score]  | AP(AP@[.50:.05:.95]) 0.7628 | AP50 0.9429 | AP75 0.9095 | precision 0.9988 | recall 0.9436 | f1_score 0.9704
# Epochs: 48/200 [train][=============================================================] (1114/1114) [time] 0:07:18.61 total loss: 0.0597 [Loss ]  | classification 0.0154 | bbox_regression 0.0443
# Epochs: 48/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:16.28 total loss: 0.0441 [Score]  | AP(AP@[.50:.05:.95]) 0.7403 | AP50 0.9157 | AP75 0.8806 | precision 0.9994 | recall 0.9163 | f1_score 0.9560
# save check point: [before]: 0.044401 / [now]: 0.044083 - Saving model...
# Epochs: 49/200 [train][=============================================================] (1114/1114) [time] 0:07:14.03 total loss: 0.0582 [Loss ]  | classification 0.0146 | bbox_regression 0.0436
# Epochs: 49/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.77 total loss: 0.0450 [Score]  | AP(AP@[.50:.05:.95]) 0.7548 | AP50 0.9361 | AP75 0.8999 | precision 0.9994 | recall 0.9368 | f1_score 0.9671
# Epochs: 50/200 [train][=============================================================] (1114/1114) [time] 0:07:29.11 total loss: 0.0579 [Loss ]  | classification 0.0145 | bbox_regression 0.0434
# Epochs: 50/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.79 total loss: 0.0448 [Score]  | AP(AP@[.50:.05:.95]) 0.7606 | AP50 0.9390 | AP75 0.9083 | precision 0.9994 | recall 0.9396 | f1_score 0.9686
# Epochs: 51/200 [train][=============================================================] (1114/1114) [time] 0:07:12.94 total loss: 0.0598 [Loss ]  | classification 0.0156 | bbox_regression 0.0441
# Epochs: 51/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.69 total loss: 0.0463 [Score]  | AP(AP@[.50:.05:.95]) 0.7492 | AP50 0.9281 | AP75 0.8934 | precision 0.9982 | recall 0.9288 | f1_score 0.9622
# Epochs: 52/200 [train][=============================================================] (1114/1114) [time] 0:07:12.12 total loss: 0.0575 [Loss ]  | classification 0.0145 | bbox_regression 0.0430
# Epochs: 52/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.67 total loss: 0.0500 [Score]  | AP(AP@[.50:.05:.95]) 0.7609 | AP50 0.9401 | AP75 0.9102 | precision 0.9982 | recall 0.9408 | f1_score 0.9686
# Epochs: 53/200 [train][=============================================================] (1114/1114) [time] 0:07:08.23 total loss: 0.0568 [Loss ]  | classification 0.0141 | bbox_regression 0.0426
# Epochs: 53/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.34 total loss: 0.0468 [Score]  | AP(AP@[.50:.05:.95]) 0.7598 | AP50 0.9412 | AP75 0.9069 | precision 0.9976 | recall 0.9419 | f1_score 0.9690
# Epochs: 54/200 [train][=============================================================] (1114/1114) [time] 0:07:11.82 total loss: 0.0562 [Loss ]  | classification 0.0138 | bbox_regression 0.0424
# Epochs: 54/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:16.55 total loss: 0.0495 [Score]  | AP(AP@[.50:.05:.95]) 0.7619 | AP50 0.9418 | AP75 0.9099 | precision 0.9982 | recall 0.9425 | f1_score 0.9695
# Epochs: 55/200 [train][=============================================================] (1114/1114) [time] 0:07:10.49 total loss: 0.0563 [Loss ]  | classification 0.0135 | bbox_regression 0.0427
# Epochs: 55/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:16.29 total loss: 0.0465 [Score]  | AP(AP@[.50:.05:.95]) 0.7652 | AP50 0.9473 | AP75 0.9110 | precision 0.9976 | recall 0.9482 | f1_score 0.9723
# Epochs: 56/200 [train][=============================================================] (1114/1114) [time] 0:07:13.65 total loss: 0.0563 [Loss ]  | classification 0.0134 | bbox_regression 0.0429
# Epochs: 56/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:16.12 total loss: 0.0454 [Score]  | AP(AP@[.50:.05:.95]) 0.7586 | AP50 0.9412 | AP75 0.9044 | precision 0.9982 | recall 0.9419 | f1_score 0.9692
# Epochs: 57/200 [train][=============================================================] (1114/1114) [time] 0:06:58.93 total loss: 0.0565 [Loss ]  | classification 0.0141 | bbox_regression 0.0424
# Epochs: 57/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.86 total loss: 0.0462 [Score]  | AP(AP@[.50:.05:.95]) 0.7551 | AP50 0.9338 | AP75 0.9008 | precision 0.9976 | recall 0.9345 | f1_score 0.9650
# Epochs: 58/200 [train][=============================================================] (1114/1114) [time] 0:07:16.51 total loss: 0.0541 [Loss ]  | classification 0.0124 | bbox_regression 0.0417
# Epochs: 58/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:14.98 total loss: 0.0525 [Score]  | AP(AP@[.50:.05:.95]) 0.7614 | AP50 0.9381 | AP75 0.9111 | precision 0.9976 | recall 0.9391 | f1_score 0.9674
# Epochs: 59/200 [train][=============================================================] (1114/1114) [time] 0:07:36.99 total loss: 0.0550 [Loss ]  | classification 0.0128 | bbox_regression 0.0422
# Epochs: 59/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.80 total loss: 0.0534 [Score]  | AP(AP@[.50:.05:.95]) 0.7507 | AP50 0.9263 | AP75 0.8932 | precision 0.9975 | recall 0.9271 | f1_score 0.9610
# Epochs: 60/200 [train][=============================================================] (1114/1114) [time] 0:07:17.46 total loss: 0.0550 [Loss ]  | classification 0.0133 | bbox_regression 0.0417
# Epochs: 60/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:14.76 total loss: 0.0739 [Score]  | AP(AP@[.50:.05:.95]) 0.7745 | AP50 0.9562 | AP75 0.9247 | precision 0.9970 | recall 0.9573 | f1_score 0.9768
# Epochs: 61/200 [train][=============================================================] (1114/1114) [time] 0:07:00.01 total loss: 0.0542 [Loss ]  | classification 0.0125 | bbox_regression 0.0417
# Epochs: 61/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:14.62 total loss: 0.0489 [Score]  | AP(AP@[.50:.05:.95]) 0.7590 | AP50 0.9365 | AP75 0.9057 | precision 0.9976 | recall 0.9374 | f1_score 0.9665
# Epochs: 62/200 [train][=============================================================] (1114/1114) [time] 0:07:32.61 total loss: 0.0525 [Loss ]  | classification 0.0119 | bbox_regression 0.0406
# Epochs: 62/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.52 total loss: 0.0485 [Score]  | AP(AP@[.50:.05:.95]) 0.7647 | AP50 0.9423 | AP75 0.9113 | precision 0.9976 | recall 0.9431 | f1_score 0.9696
# Epochs: 63/200 [train][=============================================================] (1114/1114) [time] 0:07:08.78 total loss: 0.0551 [Loss ]  | classification 0.0131 | bbox_regression 0.0421
# Epochs: 63/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:13.09 total loss: 0.0490 [Score]  | AP(AP@[.50:.05:.95]) 0.7626 | AP50 0.9416 | AP75 0.9102 | precision 0.9976 | recall 0.9425 | f1_score 0.9693
# Epochs: 64/200 [train][=============================================================] (1114/1114) [time] 0:07:27.44 total loss: 0.0530 [Loss ]  | classification 0.0115 | bbox_regression 0.0415
# Epochs: 64/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:12.69 total loss: 0.0485 [Score]  | AP(AP@[.50:.05:.95]) 0.7659 | AP50 0.9445 | AP75 0.9151 | precision 0.9976 | recall 0.9453 | f1_score 0.9708
# Epochs: 65/200 [train][=============================================================] (1114/1114) [time] 0:07:10.96 total loss: 0.0535 [Loss ]  | classification 0.0115 | bbox_regression 0.0420
# Epochs: 65/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:13.69 total loss: 0.0469 [Score]  | AP(AP@[.50:.05:.95]) 0.7676 | AP50 0.9457 | AP75 0.9149 | precision 0.9976 | recall 0.9465 | f1_score 0.9714
# Epochs: 66/200 [train][=============================================================] (1114/1114) [time] 0:07:07.29 total loss: 0.0522 [Loss ]  | classification 0.0113 | bbox_regression 0.0409
# Epochs: 66/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:13.96 total loss: 0.0487 [Score]  | AP(AP@[.50:.05:.95]) 0.7662 | AP50 0.9457 | AP75 0.9143 | precision 0.9976 | recall 0.9465 | f1_score 0.9714
# Epochs: 67/200 [train][=============================================================] (1114/1114) [time] 0:07:11.16 total loss: 0.0529 [Loss ]  | classification 0.0115 | bbox_regression 0.0414
# Epochs: 67/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:16.16 total loss: 0.0513 [Score]  | AP(AP@[.50:.05:.95]) 0.7645 | AP50 0.9444 | AP75 0.9131 | precision 0.9976 | recall 0.9453 | f1_score 0.9708
# Epochs: 68/200 [train][=============================================================] (1114/1114) [time] 0:06:57.44 total loss: 0.0527 [Loss ]  | classification 0.0115 | bbox_regression 0.0412
# Epochs: 68/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.64 total loss: 0.0509 [Score]  | AP(AP@[.50:.05:.95]) 0.7715 | AP50 0.9513 | AP75 0.9187 | precision 0.9976 | recall 0.9522 | f1_score 0.9744
# Epochs: 69/200 [train][=============================================================] (1114/1114) [time] 0:07:25.09 total loss: 0.0511 [Loss ]  | classification 0.0110 | bbox_regression 0.0401
# Epochs: 69/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:16.22 total loss: 0.0500 [Score]  | AP(AP@[.50:.05:.95]) 0.7648 | AP50 0.9445 | AP75 0.9114 | precision 0.9976 | recall 0.9453 | f1_score 0.9708
# Epochs: 70/200 [train][=============================================================] (1114/1114) [time] 0:07:21.77 total loss: 0.0540 [Loss ]  | classification 0.0123 | bbox_regression 0.0417
# Epochs: 70/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:17.13 total loss: 0.0502 [Score]  | AP(AP@[.50:.05:.95]) 0.7676 | AP50 0.9473 | AP75 0.9148 | precision 0.9976 | recall 0.9482 | f1_score 0.9723
# Epochs: 71/200 [train][=============================================================] (1114/1114) [time] 0:07:25.56 total loss: 0.0518 [Loss ]  | classification 0.0111 | bbox_regression 0.0406
# Epochs: 71/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.59 total loss: 0.0501 [Score]  | AP(AP@[.50:.05:.95]) 0.7694 | AP50 0.9485 | AP75 0.9159 | precision 0.9976 | recall 0.9493 | f1_score 0.9729
# Epochs: 72/200 [train][=============================================================] (1114/1114) [time] 0:07:03.10 total loss: 0.0519 [Loss ]  | classification 0.0110 | bbox_regression 0.0409
# Epochs: 72/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:16.41 total loss: 0.0498 [Score]  | AP(AP@[.50:.05:.95]) 0.7690 | AP50 0.9474 | AP75 0.9154 | precision 0.9976 | recall 0.9482 | f1_score 0.9723
# Epochs: 73/200 [train][=============================================================] (1114/1114) [time] 0:07:28.28 total loss: 0.0527 [Loss ]  | classification 0.0112 | bbox_regression 0.0416
# Epochs: 73/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:16.75 total loss: 0.0498 [Score]  | AP(AP@[.50:.05:.95]) 0.7681 | AP50 0.9468 | AP75 0.9143 | precision 0.9976 | recall 0.9476 | f1_score 0.9720
# Epochs: 74/200 [train][=============================================================] (1114/1114) [time] 0:06:57.95 total loss: 0.0547 [Loss ]  | classification 0.0132 | bbox_regression 0.0415
# Epochs: 74/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:15.07 total loss: 0.0535 [Score]  | AP(AP@[.50:.05:.95]) 0.7595 | AP50 0.9421 | AP75 0.9124 | precision 0.9976 | recall 0.9431 | f1_score 0.9696
# Epochs: 75/200 [train][=============================================================] (1114/1114) [time] 0:07:04.36 total loss: 0.0580 [Loss ]  | classification 0.0150 | bbox_regression 0.0429
# Epochs: 75/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:14.20 total loss: 0.0531 [Score]  | AP(AP@[.50:.05:.95]) 0.7517 | AP50 0.9277 | AP75 0.8951 | precision 0.9969 | recall 0.9288 | f1_score 0.9617
# Epochs: 76/200 [train][=============================================================] (1114/1114) [time] 0:07:20.24 total loss: 0.0549 [Loss ]  | classification 0.0133 | bbox_regression 0.0417
# Epochs: 76/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:12.87 total loss: 0.0610 [Score]  | AP(AP@[.50:.05:.95]) 0.7611 | AP50 0.9447 | AP75 0.9020 | precision 0.9964 | recall 0.9459 | f1_score 0.9705
# Epochs: 77/200 [train][=============================================================] (1114/1114) [time] 0:06:38.23 total loss: 0.0551 [Loss ]  | classification 0.0133 | bbox_regression 0.0418
# Epochs: 77/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:12.77 total loss: 0.0695 [Score]  | AP(AP@[.50:.05:.95]) 0.7720 | AP50 0.9588 | AP75 0.9197 | precision 0.9965 | recall 0.9601 | f1_score 0.9780
# Epochs: 78/200 [train][=============================================================] (1114/1114) [time] 0:06:38.13 total loss: 0.0569 [Loss ]  | classification 0.0139 | bbox_regression 0.0430
# Epochs: 78/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:12.01 total loss: 0.0569 [Score]  | AP(AP@[.50:.05:.95]) 0.7562 | AP50 0.9347 | AP75 0.9034 | precision 0.9976 | recall 0.9356 | f1_score 0.9656
# load check point: [epoch]: 47 - Loading model...
# Epochs: 78/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:11.39 total loss: 0.0441 [Score]  | AP(AP@[.50:.05:.95]) 0.7400 | AP50 0.9157 | AP75 0.8806 | precision 0.9994 | recall 0.9163 | f1_score 0.9560
# Epochs: 78/200 [test][=============================================================] ( 309/ 309) [time] 0:01:37.66 [Score]  | AP(AP@[.50:.05:.95]) 0.7520 | AP50 0.9249 | AP75 0.8994 | precision 0.9988 | recall 0.9252 | f1_score 0.9606

# %% [markdown]
# # Result

# %%
score_dict['test']
# Out:
# {'AP(AP@[.50:.05:.95])': 0.7520287385306503,
#  'AP50': 0.92486890580577,
#  'AP75': 0.899389106874595,
#  'precision': 0.9987623762376238,
#  'recall': 0.9252465030956203,
#  'f1_score': 0.9605999285799309}

# %%
from Module.process1.model_predict_checker import model_predict_checker

# %%
Check0_Ins = model_predict_checker(predict_dict=predict_dict, k=0, idx_dict=_IDX_DICT)
over_pred_df, under_pred_df, diff_pred_df, good_id_df = Check0_Ins.make_basic_value()
# Out:
# 1. 추론에 사용된 전체 이미지의 갯수: 2472
# --------------------------------------------------------------------------------
# 1-1. GT를 가지고 있는 이미지의 갯수: 820(0.332)
# 1-2. GT를 가지고 있지 않은 이미지의 갯수: 1652(0.668)
#
#
# 2. 모델의 추론 능력
# --------------------------------------------------------------------------------
# 2-1. 모델이 GT를 찾지 못한 경우: 0
# 2-2. 모델이 GT가 없는 대상을 과하게 찾은 경우: 0
# 2-3. 총 GT의 크기 = 4359
# 2-3. 모델이 찾지 못한 GT의 크기 = 321(0.074)
# 2-4. 모델이 과도하게 찾은 GT의 크기 = 2

# %%
Check0_Ins.draw_predict_image(img_id=11196)
