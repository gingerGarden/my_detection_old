# %% [markdown]
# # Library

# %%
from Module.Global_variable import os, time, torch, np, pd, plt
from Module.utils.Convenience_Function import save_pickle, time_checker
import Module.process1.preparatory_items as p1pi
from Module.process1.index_dictionary_maker import get_index_dictionary
from Module.process1.pipeLine import model_pipeline

# %% [markdown]
# # Global Variable

# %%
# Process 시작 전 정의 사항
#####################################################################################
_MAKE_NEW_DIRECTORY = False    # directory 생성
_MAKE_NEW_INDEX_DICT = False   # Index dictionary를 새로 생성할 것인지
# Log를 출력할 것인지
_VERBOSE = True
# Train 중 log를 저장할 것인지
_SAVE_TRAIN_LOG = True
# Time iteration log를 저장할 것인지
_SAVE_ITER_LOG = True
# 사용할 GPU 번호
_GPU_NUMBER = 0
torch.cuda.set_device(_GPU_NUMBER)   # set basic gpu
# torch._dynamo 캐시 한계치 조정
torch._dynamo.config.cache_size_limit = 64   # Default
# 모델 저장 여부
_MODEL_SAVE_BOOL = True
#####################################################################################


# 학습 간 전역 변수 설정
#####################################################################################
# process 기초 디렉터리 생성
p1pi.make_process_start_dir(makes_new=_MAKE_NEW_DIRECTORY)
# index dictionary with Data Loader
_IDX_DICT = get_index_dictionary(process_boolean=_MAKE_NEW_INDEX_DICT).process()
#####################################################################################


# Model 학습 관련 변수 설정
#####################################################################################
_PROCESS_SET_DICT = p1pi.get_process_set_dict(
    model_save=_MODEL_SAVE_BOOL,        # 모델 저장 여부
    save_iter_time_log=_SAVE_ITER_LOG,  # iteration의 time log 저장 여부
    save_train_log=_SAVE_TRAIN_LOG,     # 학습 과정에사 발생하는 주요 issue의 저장 여부
    verbose=_VERBOSE
)
_MODEL_SET_DICT = p1pi.get_model_set_dict(
    model_key="retinaNet",
    cnn_key="resnet50_v2",
    optimizer_key="AdamW"
)
_HYPER_PARAMS_DICT = p1pi.get_HP_set_dict(
    learing_rate=0.0001, weight_decay=0.005,
    T_0=20, T_mult=2, eta_min=0.00000001,
    CS_threshold=0.5,   # 모델의 추론 결과에 대하여 Confidence socre의 threshold
    iou_threshold=0.3   # NMS에 적용될 IoU의 threshold
)
# _HYPER_PARAMS_DICT = p1pi.get_HP_set_dict(
#     learing_rate=0.0001, weight_decay=0.005,
#     T_0=20, T_mult=2, eta_min=0.00000001,
#     CS_threshold=0.5,   # 모델의 추론 결과에 대하여 Confidence socre의 threshold
#     iou_threshold=0.3   # NMS에 적용될 IoU의 threshold
# )
#####################################################################################

# %% [markdown]
# # Function

# %% [markdown]
# # Process

# %%
for k in range(_PROCESS_SET_DICT["k_size"]):
    
    # Model 학습을 위한 Instance 생성
    MTnE_Ob = model_pipeline(
        p_set_dict=_PROCESS_SET_DICT, m_set_dict=_MODEL_SET_DICT, hp_dict=_HYPER_PARAMS_DICT,
        idx_dict=_IDX_DICT, gpu_num=_GPU_NUMBER
    )
    # DataLoader와 predict에 사용될 idx_dict(pred_idx_dict)를 정의한다.
    MTnE_Ob.define_k_Loader_and_idx_dict(k)
    # Model 정의
    MTnE_Ob.import_model()
    # Optimizer(Scheduler, Scaler) 정의
    MTnE_Ob.import_optimizer_and_scheduler()
    # 주요 Instance 생성
    MTnE_Ob.make_important_Instance(k)
    
    MTnE_Ob.Iter_log_Ins.make_log_file()      # 해당 Dataset에 대한 신규 Log file 생성
    MTnE_Ob.make_train_log_path_and_file(k)   # 해당 train에 대한 train_log의 경로 및 파일 생성
    MTnE_Ob.make_model_save_path(k)           # model 저장 경로 생성
    
    # 모델의 학습 및 추론 실시.
    loss_dict, score_dict, predict_dict = MTnE_Ob.model_train_and_evaluate()
    
    break
# Out:
# Epochs:  1/200 [train][=============================================================] (1114/1114) [time] 0:13:42.42 total loss: 0.1919 [Loss ]  | classification 0.1176 | bbox_regression 0.0743
# Epochs:  1/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:51.24 total loss: 0.0667 [Score]  | AP(AP@[.50:.05:.95]) 0.6833 | AP50 0.9051 | AP75 0.8345 | precision 0.9938 | recall 0.9078 | f1_score 0.9489
# save check point: [before]: inf / [now]: 0.066722 - Saving model...
# Epochs:  2/200 [train][=============================================================] (1114/1114) [time] 0:14:24.32 total loss: 0.0969 [Loss ]  | classification 0.0346 | bbox_regression 0.0623
# Epochs:  2/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:54.31 total loss: 0.0580 [Score]  | AP(AP@[.50:.05:.95]) 0.7035 | AP50 0.9025 | AP75 0.8521 | precision 0.9962 | recall 0.9044 | f1_score 0.9481
# save check point: [before]: 0.066722 / [now]: 0.057959 - Saving model...
# Epochs:  3/200 [train][=============================================================] (1114/1114) [time] 0:14:39.07 total loss: 0.0937 [Loss ]  | classification 0.0326 | bbox_regression 0.0611
# Epochs:  3/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:58.17 total loss: 0.0939 [Score]  | AP(AP@[.50:.05:.95]) 0.7437 | AP50 0.9743 | AP75 0.8900 | precision 0.9896 | recall 0.9772 | f1_score 0.9834
# Epochs:  4/200 [train][=============================================================] (1114/1114) [time] 0:14:30.32 total loss: 0.0791 [Loss ]  | classification 0.0256 | bbox_regression 0.0536
# Epochs:  4/200 [valid][=============================================================] ( 125/ 125) [time] 0:02:00.74 total loss: 0.0469 [Score]  | AP(AP@[.50:.05:.95]) 0.7623 | AP50 0.9732 | AP75 0.9139 | precision 0.9959 | recall 0.9744 | f1_score 0.9850
# save check point: [before]: 0.057959 / [now]: 0.046937 - Saving model...
# Epochs:  5/200 [train][=============================================================] (1114/1114) [time] 0:12:06.27 total loss: 0.0824 [Loss ]  | classification 0.0274 | bbox_regression 0.0551
# Epochs:  5/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:29.62 total loss: 0.0675 [Score]  | AP(AP@[.50:.05:.95]) 0.7337 | AP50 0.9631 | AP75 0.8906 | precision 0.9855 | recall 0.9649 | f1_score 0.9751
# Epochs:  6/200 [train][=============================================================] (1114/1114) [time] 0:11:13.75 total loss: 0.0838 [Loss ]  | classification 0.0279 | bbox_regression 0.0559
# Epochs:  6/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:31.57 total loss: 0.0478 [Score]  | AP(AP@[.50:.05:.95]) 0.7204 | AP50 0.9221 | AP75 0.8648 | precision 0.9982 | recall 0.9231 | f1_score 0.9592
# Epochs:  7/200 [train][=============================================================] (1114/1114) [time] 0:10:50.42 total loss: 0.0766 [Loss ]  | classification 0.0241 | bbox_regression 0.0525
# Epochs:  7/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:34.01 total loss: 0.0574 [Score]  | AP(AP@[.50:.05:.95]) 0.7559 | AP50 0.9517 | AP75 0.9155 | precision 0.9952 | recall 0.9533 | f1_score 0.9738
# Epochs:  8/200 [train][=============================================================] (1114/1114) [time] 0:11:45.55 total loss: 0.0673 [Loss ]  | classification 0.0188 | bbox_regression 0.0485
# Epochs:  8/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:32.05 total loss: 0.0463 [Score]  | AP(AP@[.50:.05:.95]) 0.7499 | AP50 0.9384 | AP75 0.9039 | precision 0.9958 | recall 0.9402 | f1_score 0.9672
# save check point: [before]: 0.046937 / [now]: 0.046340 - Saving model...
# Epochs:  9/200 [train][=============================================================] (1114/1114) [time] 0:11:44.19 total loss: 0.0624 [Loss ]  | classification 0.0170 | bbox_regression 0.0454
# Epochs:  9/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:30.58 total loss: 0.0420 [Score]  | AP(AP@[.50:.05:.95]) 0.7453 | AP50 0.9337 | AP75 0.8920 | precision 0.9994 | recall 0.9345 | f1_score 0.9659
# save check point: [before]: 0.046340 / [now]: 0.041995 - Saving model...
# Epochs: 10/200 [train][=============================================================] (1114/1114) [time] 0:11:27.71 total loss: 0.0774 [Loss ]  | classification 0.0239 | bbox_regression 0.0535
# Epochs: 10/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:34.38 total loss: 0.0534 [Score]  | AP(AP@[.50:.05:.95]) 0.7547 | AP50 0.9556 | AP75 0.9195 | precision 0.9976 | recall 0.9573 | f1_score 0.9771
# Epochs: 11/200 [train][=============================================================] (1114/1114) [time] 0:10:36.99 total loss: 0.0796 [Loss ]  | classification 0.0255 | bbox_regression 0.0542
# Epochs: 11/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:32.53 total loss: 0.0509 [Score]  | AP(AP@[.50:.05:.95]) 0.6831 | AP50 0.8670 | AP75 0.8279 | precision 0.9954 | recall 0.8691 | f1_score 0.9280
# Epochs: 12/200 [train][=============================================================] (1114/1114) [time] 0:10:45.54 total loss: 0.0736 [Loss ]  | classification 0.0211 | bbox_regression 0.0525
# Epochs: 12/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:29.80 total loss: 0.0471 [Score]  | AP(AP@[.50:.05:.95]) 0.7394 | AP50 0.9334 | AP75 0.8969 | precision 1.0000 | recall 0.9339 | f1_score 0.9658
# Epochs: 13/200 [train][=============================================================] (1114/1114) [time] 0:10:48.38 total loss: 0.0697 [Loss ]  | classification 0.0208 | bbox_regression 0.0489
# Epochs: 13/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:30.66 total loss: 0.0422 [Score]  | AP(AP@[.50:.05:.95]) 0.7418 | AP50 0.9282 | AP75 0.8950 | precision 0.9994 | recall 0.9288 | f1_score 0.9628
# Epochs: 14/200 [train][=============================================================] (1114/1114) [time] 0:11:05.05 total loss: 0.0651 [Loss ]  | classification 0.0176 | bbox_regression 0.0475
# Epochs: 14/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:32.87 total loss: 0.0412 [Score]  | AP(AP@[.50:.05:.95]) 0.7588 | AP50 0.9430 | AP75 0.9084 | precision 0.9994 | recall 0.9436 | f1_score 0.9707
# save check point: [before]: 0.041995 / [now]: 0.041157 - Saving model...
# Epochs: 15/200 [train][=============================================================] (1114/1114) [time] 0:11:09.74 total loss: 0.0621 [Loss ]  | classification 0.0168 | bbox_regression 0.0453
# Epochs: 15/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:34.38 total loss: 0.0406 [Score]  | AP(AP@[.50:.05:.95]) 0.7654 | AP50 0.9457 | AP75 0.9131 | precision 0.9994 | recall 0.9465 | f1_score 0.9722
# save check point: [before]: 0.041157 / [now]: 0.040623 - Saving model...
# Epochs: 16/200 [train][=============================================================] (1114/1114) [time] 0:10:47.79 total loss: 0.0620 [Loss ]  | classification 0.0167 | bbox_regression 0.0453
# Epochs: 16/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:31.41 total loss: 0.0441 [Score]  | AP(AP@[.50:.05:.95]) 0.7611 | AP50 0.9371 | AP75 0.9010 | precision 0.9988 | recall 0.9379 | f1_score 0.9674
# Epochs: 17/200 [train][=============================================================] (1114/1114) [time] 0:11:05.36 total loss: 0.0575 [Loss ]  | classification 0.0144 | bbox_regression 0.0431
# Epochs: 17/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:34.77 total loss: 0.0399 [Score]  | AP(AP@[.50:.05:.95]) 0.7745 | AP50 0.9548 | AP75 0.9160 | precision 0.9994 | recall 0.9556 | f1_score 0.9770
# save check point: [before]: 0.040623 / [now]: 0.039899 - Saving model...
# Epochs: 18/200 [train][=============================================================] (1114/1114) [time] 0:11:01.76 total loss: 0.0577 [Loss ]  | classification 0.0148 | bbox_regression 0.0430
# Epochs: 18/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:32.01 total loss: 0.0417 [Score]  | AP(AP@[.50:.05:.95]) 0.7774 | AP50 0.9570 | AP75 0.9174 | precision 0.9994 | recall 0.9579 | f1_score 0.9782
# Epochs: 19/200 [train][=============================================================] (1114/1114) [time] 0:11:26.40 total loss: 0.0692 [Loss ]  | classification 0.0205 | bbox_regression 0.0487
# Epochs: 19/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:34.50 total loss: 0.0886 [Score]  | AP(AP@[.50:.05:.95]) 0.7028 | AP50 0.8870 | AP75 0.8506 | precision 0.9924 | recall 0.8884 | f1_score 0.9375
# Epochs: 20/200 [train][=============================================================] (1114/1114) [time] 0:10:37.13 total loss: 0.0753 [Loss ]  | classification 0.0240 | bbox_regression 0.0513
# Epochs: 20/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:37.00 total loss: 0.0492 [Score]  | AP(AP@[.50:.05:.95]) 0.7268 | AP50 0.9065 | AP75 0.8789 | precision 0.9981 | recall 0.9077 | f1_score 0.9508
# Epochs: 21/200 [train][=============================================================] (1114/1114) [time] 0:11:03.26 total loss: 0.0704 [Loss ]  | classification 0.0203 | bbox_regression 0.0501
# Epochs: 21/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:34.06 total loss: 0.0458 [Score]  | AP(AP@[.50:.05:.95]) 0.7324 | AP50 0.9215 | AP75 0.8843 | precision 0.9994 | recall 0.9226 | f1_score 0.9594
# Epochs: 22/200 [train][=============================================================] (1114/1114) [time] 0:11:17.79 total loss: 0.0684 [Loss ]  | classification 0.0191 | bbox_regression 0.0492
# Epochs: 22/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:33.98 total loss: 0.0462 [Score]  | AP(AP@[.50:.05:.95]) 0.7236 | AP50 0.9008 | AP75 0.8630 | precision 0.9987 | recall 0.9021 | f1_score 0.9479
# Epochs: 23/200 [train][=============================================================] (1114/1114) [time] 0:11:01.19 total loss: 0.0664 [Loss ]  | classification 0.0178 | bbox_regression 0.0486
# Epochs: 23/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:35.22 total loss: 0.0477 [Score]  | AP(AP@[.50:.05:.95]) 0.7563 | AP50 0.9445 | AP75 0.9002 | precision 0.9988 | recall 0.9459 | f1_score 0.9716
# Epochs: 24/200 [train][=============================================================] (1114/1114) [time] 0:11:10.77 total loss: 0.0658 [Loss ]  | classification 0.0182 | bbox_regression 0.0477
# Epochs: 24/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:32.26 total loss: 0.0429 [Score]  | AP(AP@[.50:.05:.95]) 0.7256 | AP50 0.9069 | AP75 0.8679 | precision 0.9987 | recall 0.9083 | f1_score 0.9514
# Epochs: 25/200 [train][=============================================================] (1114/1114) [time] 0:10:58.89 total loss: 0.0638 [Loss ]  | classification 0.0171 | bbox_regression 0.0467
# Epochs: 25/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:33.50 total loss: 0.0434 [Score]  | AP(AP@[.50:.05:.95]) 0.7707 | AP50 0.9684 | AP75 0.9274 | precision 0.9988 | recall 0.9698 | f1_score 0.9841
# Epochs: 26/200 [train][=============================================================] (1114/1114) [time] 0:11:07.47 total loss: 0.0613 [Loss ]  | classification 0.0163 | bbox_regression 0.0450
# Epochs: 26/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:35.09 total loss: 0.0568 [Score]  | AP(AP@[.50:.05:.95]) 0.7665 | AP50 0.9483 | AP75 0.9122 | precision 0.9958 | recall 0.9505 | f1_score 0.9726
# Epochs: 27/200 [train][=============================================================] (1114/1114) [time] 0:11:12.71 total loss: 0.0620 [Loss ]  | classification 0.0165 | bbox_regression 0.0455
# Epochs: 27/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:32.36 total loss: 0.0417 [Score]  | AP(AP@[.50:.05:.95]) 0.7722 | AP50 0.9646 | AP75 0.9214 | precision 0.9994 | recall 0.9653 | f1_score 0.9820
# Epochs: 28/200 [train][=============================================================] (1114/1114) [time] 0:11:13.48 total loss: 0.0591 [Loss ]  | classification 0.0155 | bbox_regression 0.0436
# Epochs: 28/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:34.09 total loss: 0.0407 [Score]  | AP(AP@[.50:.05:.95]) 0.7769 | AP50 0.9568 | AP75 0.9299 | precision 0.9994 | recall 0.9579 | f1_score 0.9782
# Epochs: 29/200 [train][=============================================================] (1114/1114) [time] 0:10:37.63 total loss: 0.0593 [Loss ]  | classification 0.0160 | bbox_regression 0.0433
# Epochs: 29/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:34.24 total loss: 0.0443 [Score]  | AP(AP@[.50:.05:.95]) 0.7564 | AP50 0.9348 | AP75 0.9102 | precision 0.9994 | recall 0.9356 | f1_score 0.9665
# Epochs: 30/200 [train][=============================================================] (1114/1114) [time] 0:11:00.20 total loss: 0.0566 [Loss ]  | classification 0.0143 | bbox_regression 0.0423
# Epochs: 30/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:33.15 total loss: 0.0391 [Score]  | AP(AP@[.50:.05:.95]) 0.7831 | AP50 0.9624 | AP75 0.9356 | precision 0.9988 | recall 0.9636 | f1_score 0.9809
# save check point: [before]: 0.039899 / [now]: 0.039141 - Saving model...
# Epochs: 31/200 [train][=============================================================] (1114/1114) [time] 0:11:12.31 total loss: 0.0568 [Loss ]  | classification 0.0143 | bbox_regression 0.0425
# Epochs: 31/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:33.41 total loss: 0.0404 [Score]  | AP(AP@[.50:.05:.95]) 0.7760 | AP50 0.9531 | AP75 0.9231 | precision 0.9988 | recall 0.9545 | f1_score 0.9761
# Epochs: 32/200 [train][=============================================================] (1114/1114) [time] 0:11:44.55 total loss: 0.0552 [Loss ]  | classification 0.0138 | bbox_regression 0.0413
# Epochs: 32/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:33.40 total loss: 0.0399 [Score]  | AP(AP@[.50:.05:.95]) 0.7722 | AP50 0.9457 | AP75 0.9210 | precision 0.9988 | recall 0.9471 | f1_score 0.9722
# Epochs: 33/200 [train][=============================================================] (1114/1114) [time] 0:11:43.14 total loss: 0.0531 [Loss ]  | classification 0.0129 | bbox_regression 0.0401
# Epochs: 33/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:37.26 total loss: 0.0391 [Score]  | AP(AP@[.50:.05:.95]) 0.7800 | AP50 0.9554 | AP75 0.9278 | precision 0.9988 | recall 0.9567 | f1_score 0.9773
# save check point: [before]: 0.039141 / [now]: 0.039083 - Saving model...
# Epochs: 34/200 [train][=============================================================] (1114/1114) [time] 0:11:19.66 total loss: 0.0528 [Loss ]  | classification 0.0128 | bbox_regression 0.0400
# Epochs: 34/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:33.73 total loss: 0.0388 [Score]  | AP(AP@[.50:.05:.95]) 0.7771 | AP50 0.9509 | AP75 0.9240 | precision 0.9988 | recall 0.9522 | f1_score 0.9749
# save check point: [before]: 0.039083 / [now]: 0.038794 - Saving model...
# Epochs: 35/200 [train][=============================================================] (1114/1114) [time] 0:10:48.81 total loss: 0.0511 [Loss ]  | classification 0.0120 | bbox_regression 0.0391
# Epochs: 35/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:30.00 total loss: 0.0391 [Score]  | AP(AP@[.50:.05:.95]) 0.7796 | AP50 0.9526 | AP75 0.9222 | precision 0.9988 | recall 0.9539 | f1_score 0.9758
# Epochs: 36/200 [train][=============================================================] (1114/1114) [time] 0:11:28.95 total loss: 0.0505 [Loss ]  | classification 0.0119 | bbox_regression 0.0386
# Epochs: 36/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:33.05 total loss: 0.0392 [Score]  | AP(AP@[.50:.05:.95]) 0.7761 | AP50 0.9481 | AP75 0.9185 | precision 0.9988 | recall 0.9493 | f1_score 0.9734
# Epochs: 37/200 [train][=============================================================] (1114/1114) [time] 0:11:02.11 total loss: 0.0560 [Loss ]  | classification 0.0138 | bbox_regression 0.0421
# Epochs: 37/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:30.97 total loss: 0.0512 [Score]  | AP(AP@[.50:.05:.95]) 0.6997 | AP50 0.8766 | AP75 0.8491 | precision 0.9994 | recall 0.8776 | f1_score 0.9345
# Epochs: 38/200 [train][=============================================================] (1114/1114) [time] 0:10:51.17 total loss: 0.0661 [Loss ]  | classification 0.0177 | bbox_regression 0.0484
# Epochs: 38/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:32.54 total loss: 0.0499 [Score]  | AP(AP@[.50:.05:.95]) 0.7627 | AP50 0.9539 | AP75 0.9197 | precision 0.9994 | recall 0.9550 | f1_score 0.9767
# Epochs: 39/200 [train][=============================================================] (1114/1114) [time] 0:11:20.65 total loss: 0.0629 [Loss ]  | classification 0.0171 | bbox_regression 0.0457
# Epochs: 39/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:32.73 total loss: 0.0437 [Score]  | AP(AP@[.50:.05:.95]) 0.7821 | AP50 0.9705 | AP75 0.9415 | precision 0.9994 | recall 0.9715 | f1_score 0.9853
# Epochs: 40/200 [train][=============================================================] (1114/1114) [time] 0:10:57.97 total loss: 0.0660 [Loss ]  | classification 0.0187 | bbox_regression 0.0473
# Epochs: 40/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:33.32 total loss: 0.0454 [Score]  | AP(AP@[.50:.05:.95]) 0.7428 | AP50 0.9221 | AP75 0.8952 | precision 0.9982 | recall 0.9231 | f1_score 0.9592
# Epochs: 41/200 [train][=============================================================] (1114/1114) [time] 0:10:57.63 total loss: 0.0623 [Loss ]  | classification 0.0166 | bbox_regression 0.0457
# Epochs: 41/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:33.95 total loss: 0.0570 [Score]  | AP(AP@[.50:.05:.95]) 0.7331 | AP50 0.9005 | AP75 0.8804 | precision 0.9981 | recall 0.9021 | f1_score 0.9477
# Epochs: 42/200 [train][=============================================================] (1114/1114) [time] 0:11:22.82 total loss: 0.0628 [Loss ]  | classification 0.0167 | bbox_regression 0.0461
# Epochs: 42/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:33.65 total loss: 0.0452 [Score]  | AP(AP@[.50:.05:.95]) 0.7342 | AP50 0.9160 | AP75 0.8752 | precision 0.9988 | recall 0.9169 | f1_score 0.9561
# Epochs: 43/200 [train][=============================================================] (1114/1114) [time] 0:11:31.01 total loss: 0.0621 [Loss ]  | classification 0.0163 | bbox_regression 0.0458
# Epochs: 43/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:33.91 total loss: 0.0469 [Score]  | AP(AP@[.50:.05:.95]) 0.7733 | AP50 0.9612 | AP75 0.9306 | precision 0.9994 | recall 0.9619 | f1_score 0.9803
# Epochs: 44/200 [train][=============================================================] (1114/1114) [time] 0:11:37.88 total loss: 0.0624 [Loss ]  | classification 0.0166 | bbox_regression 0.0458
# Epochs: 44/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:34.52 total loss: 0.0541 [Score]  | AP(AP@[.50:.05:.95]) 0.7647 | AP50 0.9528 | AP75 0.9240 | precision 0.9976 | recall 0.9544 | f1_score 0.9756
# Epochs: 45/200 [train][=============================================================] (1114/1114) [time] 0:10:47.21 total loss: 0.0609 [Loss ]  | classification 0.0159 | bbox_regression 0.0450
# Epochs: 45/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:32.00 total loss: 0.0476 [Score]  | AP(AP@[.50:.05:.95]) 0.7256 | AP50 0.8922 | AP75 0.8771 | precision 0.9924 | recall 0.8936 | f1_score 0.9404
# Epochs: 46/200 [train][=============================================================] (1114/1114) [time] 0:11:02.55 total loss: 0.0620 [Loss ]  | classification 0.0162 | bbox_regression 0.0458
# Epochs: 46/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:32.18 total loss: 0.0409 [Score]  | AP(AP@[.50:.05:.95]) 0.7312 | AP50 0.8999 | AP75 0.8765 | precision 0.9994 | recall 0.9009 | f1_score 0.9476
# Epochs: 47/200 [train][=============================================================] (1114/1114) [time] 0:11:35.61 total loss: 0.0607 [Loss ]  | classification 0.0158 | bbox_regression 0.0449
# Epochs: 47/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:34.86 total loss: 0.0450 [Score]  | AP(AP@[.50:.05:.95]) 0.7595 | AP50 0.9403 | AP75 0.9163 | precision 0.9988 | recall 0.9419 | f1_score 0.9695
# Epochs: 48/200 [train][=============================================================] (1114/1114) [time] 0:11:19.08 total loss: 0.0597 [Loss ]  | classification 0.0151 | bbox_regression 0.0446
# Epochs: 48/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:32.95 total loss: 0.0400 [Score]  | AP(AP@[.50:.05:.95]) 0.7538 | AP50 0.9256 | AP75 0.8961 | precision 0.9975 | recall 0.9271 | f1_score 0.9610
# Epochs: 49/200 [train][=============================================================] (1114/1114) [time] 0:11:49.77 total loss: 0.0578 [Loss ]  | classification 0.0141 | bbox_regression 0.0437
# Epochs: 49/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:35.39 total loss: 0.0458 [Score]  | AP(AP@[.50:.05:.95]) 0.7834 | AP50 0.9631 | AP75 0.9350 | precision 0.9982 | recall 0.9647 | f1_score 0.9812
# Epochs: 50/200 [train][=============================================================] (1114/1114) [time] 0:11:17.76 total loss: 0.0574 [Loss ]  | classification 0.0143 | bbox_regression 0.0431
# Epochs: 50/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:32.85 total loss: 0.0417 [Score]  | AP(AP@[.50:.05:.95]) 0.7805 | AP50 0.9623 | AP75 0.9323 | precision 0.9982 | recall 0.9636 | f1_score 0.9806
# Epochs: 51/200 [train][=============================================================] (1114/1114) [time] 0:10:47.33 total loss: 0.0587 [Loss ]  | classification 0.0150 | bbox_regression 0.0438
# Epochs: 51/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:34.67 total loss: 0.0421 [Score]  | AP(AP@[.50:.05:.95]) 0.7608 | AP50 0.9368 | AP75 0.9094 | precision 0.9982 | recall 0.9379 | f1_score 0.9671
# Epochs: 52/200 [train][=============================================================] (1114/1114) [time] 0:11:17.60 total loss: 0.0563 [Loss ]  | classification 0.0143 | bbox_regression 0.0419
# Epochs: 52/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:32.26 total loss: 0.0402 [Score]  | AP(AP@[.50:.05:.95]) 0.7737 | AP50 0.9545 | AP75 0.9296 | precision 0.9988 | recall 0.9556 | f1_score 0.9767
# Epochs: 53/200 [train][=============================================================] (1114/1114) [time] 0:11:39.96 total loss: 0.0552 [Loss ]  | classification 0.0137 | bbox_regression 0.0416
# Epochs: 53/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:34.35 total loss: 0.0419 [Score]  | AP(AP@[.50:.05:.95]) 0.7826 | AP50 0.9595 | AP75 0.9303 | precision 0.9982 | recall 0.9607 | f1_score 0.9791
# Epochs: 54/200 [train][=============================================================] (1114/1114) [time] 0:11:22.28 total loss: 0.0543 [Loss ]  | classification 0.0129 | bbox_regression 0.0414
# Epochs: 54/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:33.93 total loss: 0.0419 [Score]  | AP(AP@[.50:.05:.95]) 0.7618 | AP50 0.9359 | AP75 0.9082 | precision 0.9982 | recall 0.9374 | f1_score 0.9668
# Epochs: 55/200 [train][=============================================================] (1114/1114) [time] 0:11:34.56 total loss: 0.0543 [Loss ]  | classification 0.0128 | bbox_regression 0.0414
# Epochs: 55/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:31.10 total loss: 0.0413 [Score]  | AP(AP@[.50:.05:.95]) 0.7779 | AP50 0.9590 | AP75 0.9281 | precision 0.9982 | recall 0.9601 | f1_score 0.9788
# Epochs: 56/200 [train][=============================================================] (1114/1114) [time] 0:10:44.20 total loss: 0.0538 [Loss ]  | classification 0.0125 | bbox_regression 0.0413
# Epochs: 56/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:35.40 total loss: 0.0422 [Score]  | AP(AP@[.50:.05:.95]) 0.7746 | AP50 0.9534 | AP75 0.9215 | precision 0.9982 | recall 0.9544 | f1_score 0.9758
# Epochs: 57/200 [train][=============================================================] (1114/1114) [time] 0:11:11.10 total loss: 0.0534 [Loss ]  | classification 0.0130 | bbox_regression 0.0404
# Epochs: 57/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:36.81 total loss: 0.0416 [Score]  | AP(AP@[.50:.05:.95]) 0.7816 | AP50 0.9666 | AP75 0.9339 | precision 0.9988 | recall 0.9675 | f1_score 0.9829
# Epochs: 58/200 [train][=============================================================] (1114/1114) [time] 0:11:18.26 total loss: 0.0511 [Loss ]  | classification 0.0113 | bbox_regression 0.0398
# Epochs: 58/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:33.39 total loss: 0.0415 [Score]  | AP(AP@[.50:.05:.95]) 0.7658 | AP50 0.9396 | AP75 0.9143 | precision 0.9976 | recall 0.9408 | f1_score 0.9683
# Epochs: 59/200 [train][=============================================================] (1114/1114) [time] 0:11:03.81 total loss: 0.0530 [Loss ]  | classification 0.0131 | bbox_regression 0.0399
# Epochs: 59/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:34.42 total loss: 0.0412 [Score]  | AP(AP@[.50:.05:.95]) 0.7514 | AP50 0.9163 | AP75 0.8918 | precision 0.9981 | recall 0.9174 | f1_score 0.9561
# Epochs: 60/200 [train][=============================================================] (1114/1114) [time] 0:10:52.76 total loss: 0.0518 [Loss ]  | classification 0.0125 | bbox_regression 0.0392
# Epochs: 60/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:35.75 total loss: 0.0503 [Score]  | AP(AP@[.50:.05:.95]) 0.7898 | AP50 0.9626 | AP75 0.9331 | precision 0.9971 | recall 0.9641 | f1_score 0.9803
# Epochs: 61/200 [train][=============================================================] (1114/1114) [time] 0:11:20.49 total loss: 0.0505 [Loss ]  | classification 0.0115 | bbox_regression 0.0390
# Epochs: 61/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:33.26 total loss: 0.0405 [Score]  | AP(AP@[.50:.05:.95]) 0.7849 | AP50 0.9558 | AP75 0.9283 | precision 0.9994 | recall 0.9567 | f1_score 0.9776
# Epochs: 62/200 [train][=============================================================] (1114/1114) [time] 0:11:33.99 total loss: 0.0484 [Loss ]  | classification 0.0106 | bbox_regression 0.0377
# Epochs: 62/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:34.14 total loss: 0.0394 [Score]  | AP(AP@[.50:.05:.95]) 0.7750 | AP50 0.9471 | AP75 0.9197 | precision 0.9988 | recall 0.9482 | f1_score 0.9728
# Epochs: 63/200 [train][=============================================================] (1114/1114) [time] 0:11:49.07 total loss: 0.0506 [Loss ]  | classification 0.0117 | bbox_regression 0.0388
# Epochs: 63/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:31.37 total loss: 0.0409 [Score]  | AP(AP@[.50:.05:.95]) 0.7778 | AP50 0.9481 | AP75 0.9205 | precision 0.9976 | recall 0.9493 | f1_score 0.9729
# Epochs: 64/200 [train][=============================================================] (1114/1114) [time] 0:11:08.85 total loss: 0.0478 [Loss ]  | classification 0.0100 | bbox_regression 0.0378
# Epochs: 64/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:28.62 total loss: 0.0410 [Score]  | AP(AP@[.50:.05:.95]) 0.7869 | AP50 0.9607 | AP75 0.9315 | precision 0.9976 | recall 0.9618 | f1_score 0.9794
# load check point: [epoch]: 33 - Loading model...
# Epochs: 64/200 [valid][=============================================================] ( 125/ 125) [time] 0:01:27.32 total loss: 0.0388 [Score]  | AP(AP@[.50:.05:.95]) 0.7771 | AP50 0.9509 | AP75 0.9240 | precision 0.9988 | recall 0.9522 | f1_score 0.9749
# Epochs: 64/200 [test][=============================================================] ( 309/ 309) [time] 0:03:21.61 [Score]  | AP(AP@[.50:.05:.95]) 0.7760 | AP50 0.9443 | AP75 0.9197 | precision 0.9990 | recall 0.9447 | f1_score 0.9711

# %% [markdown]
# # Result

# %%
score_dict['test']
# Out:
# {'AP(AP@[.50:.05:.95])': 0.7760329494150386,
#  'AP50': 0.9443438623559908,
#  'AP75': 0.9196618545578324,
#  'precision': 0.9990298326461314,
#  'recall': 0.9447247706422018,
#  'f1_score': 0.9711187080042438}

# %%
from Module.process1.model_predict_checker import model_predict_checker

# %%
Check0_Ins = model_predict_checker(predict_dict=predict_dict, k=0, idx_dict=_IDX_DICT)
over_pred_df, under_pred_df, diff_pred_df, good_id_df = Check0_Ins.make_basic_value()
# Out:
# 1. 추론에 사용된 전체 이미지의 갯수: 2472
# --------------------------------------------------------------------------------
# 1-1. GT를 가지고 있는 이미지의 갯수: 820(0.332)
# 1-2. GT를 가지고 있지 않은 이미지의 갯수: 1652(0.668)
#
#
# 2. 모델의 추론 능력
# --------------------------------------------------------------------------------
# 2-1. 모델이 GT를 찾지 못한 경우: 0
# 2-2. 모델이 GT가 없는 대상을 과하게 찾은 경우: 0
# 2-3. 총 GT의 크기 = 4359
# 2-3. 모델이 찾지 못한 GT의 크기 = 236(0.054)
# 2-4. 모델이 과도하게 찾은 GT의 크기 = 0

# %%
Check0_Ins.draw_predict_image(img_id=12241)
